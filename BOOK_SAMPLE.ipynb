# %% [markdown]
# <a href="https://colab.research.google.com/github/AbinayaIT23/BookScape-Explorer/blob/main/BOOK_SAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
api_key = "your_api_key"

# %%
def scrap(query,api_key):
  url = "https://www.googleapis.com/books/v1/volumes"
  params = {
          "q": query,
          "key": api_key,
          "maxResults":40
      }
  response = requests.get(url, params=params)
  return  response

# %%
scrap(api_key,'python')
# Out:
# <Response [400]>

# %%
def extract_data(data)
# Out:
#   File "<ipython-input-13-48052c0c3fab>", line 1
#     def extract_data(data)
#                           ^
# SyntaxError: expected ':'

# %%
data = scrap('python',api_key)
d = data.json()

# %%
d
# Out:
# {'error': {'code': 400,
#   'message': 'API key not valid. Please pass a valid API key.',
#   'errors': [{'message': 'API key not valid. Please pass a valid API key.',
#     'domain': 'global',
#     'reason': 'badRequest'}],
#   'status': 'INVALID_ARGUMENT',
#   'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo',
#     'reason': 'API_KEY_INVALID',
#     'domain': 'googleapis.com',
#     'metadata': {'service': 'books.googleapis.com'}},
#    {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage',
#     'locale': 'en-US',
#     'message': 'API key not valid. Please pass a valid API key.'}]}}

# %%
len

# %%
d
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1739,
#  'items': [{'kind': 'books#volume',
#    'id': 'DjxZEAAAQBAJ',
#    'etag': 'DQl8waVYi24',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DjxZEAAAQBAJ',
#    'volumeInfo': {'title': 'The Python Book',
#     'authors': ['Rob Mastrodomenico'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2022-01-13',
# ...

# %%
d.keys()
# Out:
# dict_keys(['kind', 'totalItems', 'items'])

# %%
len(d['items'])
# Out:
# 10

# %%
d['items'][0]['id']
# Out:
# 'FwKHDwAAQBAJ'

# %%
for i in d['items']:
  print(i['id'])
# Out:
# DjxZEAAAQBAJ
# nEJ-jcYF2fMC
# C3ymDwAAQBAJ
# bIZHCgAAQBAJ
# KabKDAAAQBAJ
# KZvM0AEACAAJ
# w1v6DwAAQBAJ
# kcGrEAAAQBAJ
# -_6dEAAAQBAJ
# igYvDwAAQBAJ
# __wvEQAAQBAJ
# EVuk7eqhWiwC
# HFeGvgEACAAJ
# VNozDwAAQBAJ
# FQlBEAAAQBAJ
# 10KYwCZxSdEC
# 9dW8DwAAQBAJ
# S_SJ2LaZH8EC
# aJQILlLxRmAC
# 3Kd9DwAAQBAJ
# ftA0yk1Z92wC
# 1HxWGezDZcgC
# BcN0swEACAAJ
# 6omNDQAAQBAJ
# bi59DwAAQBAJ
# VxDGDwAAQBAJ
# fKZwzgEACAAJ
# P5DUDwAAQBAJ
# E_ILEAAAQBAJ
# 8mN0EAAAQBAJ
# ZB9sDwAAQBAJ
# pLe9V19eywgC
# bTUFCAAAQBAJ
# 7GUKEAAAQBAJ
# _J5lEAAAQBAJ
# iIpGEAAAQBAJ
# J5Y2EAAAQBAJ
# spNqDwAAQBAJ
# JnR9hQA3SncC
# UiM3DwAAQBAJ

# %%
data = {'t' : d['items'][0]['volumeInfo']['title'],
's_t' : d['items'][0]['volumeInfo'].get('subtitle','NA'),
'id' : d['items'][0]['id']}

# %%
data = {'t' : d['items'][4]['volumeInfo']['title'],
's_t' : d['items'][4]['volumeInfo']['subtitle'],
'id' : d['items'][4]['id']}

# %%
data
# Out:
# {'t': 'The Python Book', 's_t': 'NA', 'id': 'DjxZEAAAQBAJ'}

# %%
all_data=[]
for i in d['items']:
    data = {'t' : i['volumeInfo']['title'],
    's_t' : i['volumeInfo'].get('subtitle','NA'),
    'id' : i['id']}
    all_data.append(data)

# %%
all_data
# Out:
# [{'t': 'The Python Book', 's_t': 'NA', 'id': 'DjxZEAAAQBAJ'},
#  {'t': 'Learning Python', 's_t': 'NA', 'id': 'nEJ-jcYF2fMC'},
#  {'t': 'Python Programming in Context', 's_t': 'NA', 'id': 'C3ymDwAAQBAJ'},
#  {'t': 'Fluent Python',
#   's_t': 'Clear, Concise, and Effective Programming',
#   'id': 'bIZHCgAAQBAJ'},
#  {'t': 'Introduction to Computation and Programming Using Python, second edition',
#   's_t': 'With Application to Understanding Data',
#   'id': 'KabKDAAAQBAJ'},
#  {'t': 'Effective Python',
#   's_t': '90 Specific Ways to Write Better Python (2nd Edition)',
#   'id': 'KZvM0AEACAAJ'},
#  {'t': 'Python Crash Course, 2nd Edition',
#   's_t': 'A Hands-On, Project-Based Introduction to Programming',
#   'id': 'w1v6DwAAQBAJ'},
#  {'t': 'Python Essentials 1', 's_t': 'Beginner Course', 'id': 'kcGrEAAAQBAJ'},
#  {'t': 'Beginning Programming with Python For Dummies',
#   's_t': 'NA',
#   'id': '-_6dEAAAQBAJ'},
#  {'t': 'Python Crash Course',
# ...

# %%
d
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1694,
#  'items': [{'kind': 'books#volume',
#    'id': 'DjxZEAAAQBAJ',
#    'etag': 'V6t/yBrZt/M',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DjxZEAAAQBAJ',
#    'volumeInfo': {'title': 'The Python Book',
#     'authors': ['Rob Mastrodomenico'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2022-01-13',
# ...
